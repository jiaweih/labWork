# %%
from mpl_toolkits.basemap import Basemap, cm
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib as mpl
import pandas as pd
import datetime as dt
import pandas.stats.moments as pds
# %matplotlib inline

# %%
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize'] = 16
mpl.rcParams['lines.linewidth'] = 3
mpl.rcParams['axes.labelsize'] = 18
mpl.rcParams['legend.fontsize'] = 15
mpl.rcParams['savefig.dpi'] = 100
mpl.rcParams['figure.figsize'] = [10, 8]
mpl.rcParams['legend.loc'] = 'upper right'
mpl.rcParams['legend.frameon'] = True
mpl.rcParams['font.size'] = 12
mpl.rcParams['figure.dpi'] = 300

# %%
def plot_basemap(lat,lon,var,vmin,vmax,border=1):
    latmi   = min(lat)-border
    latmx   = max(lat)+border
    latmean = (latmi+latmx)/2.
    lonmi   = min(lon)-border
    lonmx   = max(lon)+border
    lonmean = (lonmi+lonmx)/2.
    m = Basemap(projection = 'merc',lat_0=latmean, lon_0=lonmean, llcrnrlat=latmi,
            urcrnrlat=latmx, llcrnrlon=lonmi, urcrnrlon=lonmx, resolution='i')
    m.drawcoastlines(linewidth=0.25)
    xi,yi = m(*np.meshgrid(lon,lat))
    norm = mpl.colors.Normalize(vmin,vmax)
    m.pcolormesh(xi,yi,var,cmap=cmap,norm=norm)

# %% [markdown]
# ###Mean

# %%
ifile = '/raid3/jiawei/integrated_scenarios/ulm/project2/data/statistics/wb.1970.1999.mean.nc'
nc = Dataset(ifile,'r')
lat = nc.variables['Latitude'][:]
lon = nc.variables['Longitude'][:]

# %%
nc.variables
# Out:
# OrderedDict([(u'Longitude', <netCDF4.Variable object at 0x69bfdd0>), (u'Latitude', <netCDF4.Variable object at 0x69bf5d0>), (u'Time', <netCDF4.Variable object at 0x69bfed0>), (u'Q', <netCDF4.Variable object at 0x69bfbd0>), (u'Evap', <netCDF4.Variable object at 0x69bf8d0>), (u'Rainf', <netCDF4.Variable object at 0x69bf550>), (u'SoilMoist', <netCDF4.Variable object at 0x69bff50>), (u'SWE', <netCDF4.Variable object at 0x69bf450>)])

# %%
Prec = nc.variables['Rainf'][0,:,:]
Evap = nc.variables['Evap'][0,:,:]
Runoff = nc.variables['Q'][0,:,:]

# %%
cax = [0.1,0.25,0.85,0.03]
variables = [Prec,Evap,Runoff]
varname = ['Prec','Evap','Runoff']
cmap = cm.GMT_drywet
vmin = 0.5
vmax = 4.5
grid = gridspec.GridSpec(1, 3, width_ratios=[1,1,1])
fig = plt.figure()

for idx,var in enumerate(variables):
    ax = fig.add_subplot(grid[idx])
    plot_basemap(lat,lon,var,vmin,vmax)
    ax.text(0.97, 0.97, varname[idx], verticalalignment='top', horizontalalignment='right',
                transform=ax.transAxes, color='black',fontsize=15)
    cax = plt.axes(cax)
    norm = mpl.colors.Normalize(vmin,vmax)
    cax = plt.axes(cax)
    cbar = mpl.colorbar.ColorbarBase(cax,cmap=cmap,norm=norm,orientation='horizontal',extend='both')
    cbar.ax.tick_params()
    cbar.set_label('mm/day')
fig.savefig('PEQ.mean.png')

# %% [markdown]
# ###Max

# %%
ifile = '/raid3/jiawei/integrated_scenarios/ulm/project2/data/statistics/wb.1970.1999.max.nc'
nc = Dataset(ifile,'r')
lat = nc.variables['Latitude'][:]
lon = nc.variables['Longitude'][:]

# %%
Prec = nc.variables['Rainf'][0,:,:]
Evap = nc.variables['Evap'][0,:,:]
Runoff = nc.variables['Q'][0,:,:]

# %%
cax = [0.1,0.25,0.85,0.03]
variables = [Prec,Evap,Runoff]
varname = ['Prec','Evap','Runoff']
cmap = cm.GMT_drywet
vmin = 0.5
vmax = 8.5
grid = gridspec.GridSpec(1, 3, width_ratios=[1,1,1])
fig = plt.figure()

for idx,var in enumerate(variables):
    ax = fig.add_subplot(grid[idx])
    plot_basemap(lat,lon,var,vmin,vmax)
    ax.text(0.97, 0.97, varname[idx], verticalalignment='top', horizontalalignment='right',
                transform=ax.transAxes, color='black',fontsize=15)
    cax = plt.axes(cax)
    norm = mpl.colors.Normalize(vmin,vmax)
    cax = plt.axes(cax)
    cbar = mpl.colorbar.ColorbarBase(cax,cmap=cmap,norm=norm,orientation='horizontal',extend='both')
    cbar.ax.tick_params()
    cbar.set_label('mm/day')
fig.savefig('QPE.max.png')

# %% [markdown]
# ###Min

# %%
ifile = '/raid3/jiawei/integrated_scenarios/ulm/project2/data/statistics/wb.1970.1999.min.nc'
nc = Dataset(ifile,'r')
lat = nc.variables['Latitude'][:]
lon = nc.variables['Longitude'][:]

# %%
Prec = nc.variables['Rainf'][0,:,:]
Evap = nc.variables['Evap'][0,:,:]
Runoff = nc.variables['Q'][0,:,:]

# %%
cax = [0.1,0.25,0.85,0.03]
variables = [Prec,Evap,Runoff]
varname = ['Prec','Evap','Runoff']
cmap = cm.GMT_drywet
vmin = 0
vmax = 0.5
grid = gridspec.GridSpec(1, 3, width_ratios=[1,1,1])
fig = plt.figure()

for idx,var in enumerate(variables):
    ax = fig.add_subplot(grid[idx])
    plot_basemap(lat,lon,var,vmin,vmax)
    ax.text(0.97, 0.97, varname[idx], verticalalignment='top', horizontalalignment='right',
                transform=ax.transAxes, color='black',fontsize=15)
    cax = plt.axes(cax)
    norm = mpl.colors.Normalize(vmin,vmax)
    cax = plt.axes(cax)
    cbar = mpl.colorbar.ColorbarBase(cax,cmap=cmap,norm=norm,orientation='horizontal',extend='max')
    cbar.ax.tick_params()
    cbar.set_label('mm/day')
fig.savefig('QPE.min.png')

# %% [markdown]
# ###Seasonal

# %%
nc = Dataset('/raid3/jiawei/integrated_scenarios/ulm/project2/data/statistics/wb.1970.1999.seasmean.nc','r')
lat = nc.variables['Latitude'][:]
lon = nc.variables['Longitude'][:]

# %%
Prec = nc.variables['Rainf']
Evap = nc.variables['Evap']
Runoff = nc.variables['Q']
SWE = nc.variables['SWE']
SoilMoist = nc.variables['SoilMoist']

# %%
seasonal = {'Prec':{'Winter':Prec[0,:,:],'Spring':Prec[1,:,:],'Summer':Prec[2,:,:],'Autumn':Prec[3,:,:]},
            'Evap':{'Winter':Evap[0,:,:],'Spring':Evap[1,:,:],'Summer':Evap[2,:,:],'Autumn':Evap[3,:,:]},
            'Runoff':{'Winter':Runoff[0,:,:],'Spring':Runoff[1,:,:],'Summer':Runoff[2,:,:],'Autumn':Runoff[3,:,:]},
            'SWE':{'Winter':SWE[0,:,:],'Spring':SWE[1,:,:],'Summer':SWE[2,:,:],'Autumn':SWE[3,:,:]},
            'SoilMoist':{'Winter':SoilMoist[0,:,:],'Spring':SoilMoist[1,:,:],'Summer':SoilMoist[2,:,:],'Autumn':SoilMoist[3,:,:]}}

# %%
Prec.shape
# Out:
# (4, 382, 346)

# %%
seasons = ['Winter','Spring','Summer','Autumn']
v = 'Prec'
grid = gridspec.GridSpec(2, 2, width_ratios=[1,1])
vmin = 0
vmax = 5
fig = plt.figure()
for idx,season in enumerate(seasons):
    var = seasonal[v][season]
    ax = fig.add_subplot(grid[idx])
    plot_basemap(lat,lon,var,vmin,vmax)
    ax.text(0.97, 0.97, season, verticalalignment='top', horizontalalignment='right',
              transform=ax.transAxes, color='black', fontsize=15)
    
cax = [0.1,0.08,0.85,0.03]
cax = plt.axes(cax)
norm = mpl.colors.Normalize(vmin,vmax)
cbar = mpl.colorbar.ColorbarBase(cax,cmap=cmap,norm=norm,orientation='horizontal',extend='both')
cbar.ax.tick_params()
cbar.set_label('Prec (mm/day)')
fig.savefig('seasonal.prec.png')

# %%
seasons = ['Winter','Spring','Summer','Autumn']
v = 'Evap'
vmin = 0
vmax = 2
grid = gridspec.GridSpec(2, 2, width_ratios=[1,1])
fig = plt.figure()
for idx,season in enumerate(seasons):
    var = seasonal[v][season]
    ax = fig.add_subplot(grid[idx])
    plot_basemap(lat,lon,var,vmin,vmax)
    ax.text(0.97, 0.97, season, verticalalignment='top', horizontalalignment='right',
              transform=ax.transAxes, color='black', fontsize=15)
    
cax = [0.1,0.08,0.85,0.03]
cax = plt.axes(cax)
norm = mpl.colors.Normalize(vmin,vmax)
cbar = mpl.colorbar.ColorbarBase(cax,cmap=cmap,norm=norm,orientation='horizontal',extend='both')
cbar.ax.tick_params()
cbar.set_label('Evap (mm/day)')
fig.savefig('seasonal.evap.png')

# %%
seasons = ['Winter','Spring','Summer','Autumn']
v = 'Runoff'
vmin = 1
vmax = 4.5
grid = gridspec.GridSpec(2, 2, width_ratios=[1,1])
fig = plt.figure()
for idx,season in enumerate(seasons):
    var = seasonal[v][season]
    ax = fig.add_subplot(grid[idx])
    plot_basemap(lat,lon,var,vmin,vmax)
    ax.text(0.97, 0.97, season, verticalalignment='top', horizontalalignment='right',
              transform=ax.transAxes, color='black', fontsize=15)
    
cax = [0.1,0.08,0.85,0.03]
cax = plt.axes(cax)
norm = mpl.colors.Normalize(vmin,vmax)
cbar = mpl.colorbar.ColorbarBase(cax,cmap=cmap,norm=norm,orientation='horizontal',extend='both')
cbar.ax.tick_params()
cbar.set_label('Runoff (mm/day)')
fig.savefig('seasonal.runoff.png')

# %%
seasons = ['Winter','Spring','Summer','Autumn']
v = 'SoilMoist'
vmin = 100
vmax = 1000
grid = gridspec.GridSpec(2, 2, width_ratios=[1,1])
fig = plt.figure()
for idx,season in enumerate(seasons):
    var = seasonal[v][season]
    ax = fig.add_subplot(grid[idx])
    plot_basemap(lat,lon,var,vmin,vmax)
    ax.text(0.97, 0.97, season, verticalalignment='top', horizontalalignment='right',
              transform=ax.transAxes, color='black', fontsize=15)
    
cax = [0.1,0.08,0.85,0.03]
cax = plt.axes(cax)
norm = mpl.colors.Normalize(vmin,vmax)
cbar = mpl.colorbar.ColorbarBase(cax,cmap=cmap,norm=norm,orientation='horizontal',extend='both')
cbar.ax.tick_params()
cbar.set_label('SoilMoist (mm)')
fig.savefig('seasonal.soil.png')

# %%
seasons = ['Winter','Spring','Summer','Autumn']
v = 'SWE'
vmin = 10
vmax = 600
grid = gridspec.GridSpec(2, 2, width_ratios=[1,1])
fig = plt.figure()
for idx,season in enumerate(seasons):
    var = seasonal[v][season]
    ax = fig.add_subplot(grid[idx])
    plot_basemap(lat,lon,var,vmin,vmax)
    ax.text(0.97, 0.97, season, verticalalignment='top', horizontalalignment='right',
              transform=ax.transAxes, color='black', fontsize=15)
    
cax = [0.1,0.08,0.85,0.03]
cax = plt.axes(cax)
norm = mpl.colors.Normalize(vmin,vmax)
cbar = mpl.colorbar.ColorbarBase(cax,cmap=cmap,norm=norm,orientation='horizontal',extend='both')
cbar.ax.tick_params()
cbar.set_label('SWE (mm)')
fig.savefig('seasonal.swe.png')

# %% [markdown]
# ###time series

# %%
def readflow(ncfile, ncvar, start=None, end=None):
    nc = netCDF4.Dataset(ncfile, 'r')
    jd = [dt.datetime(x.year, x.month, x.day, x.hour, x.minute, x.second)
          for x in netCDF4.num2date(nc.variables['Time'][:],
                                    nc.variables['Time'].units,
                                    nc.variables['Time'].calendar)]
    df = pd.Series(nc.variables[ncvar][:,0,0], index=jd)
    nc.close()
    if start:
        df = df[start:]
    if end:
        df = df[:end]
    return df

# %% [markdown]
# ###Prec

# %%
ifile = '/raid3/jiawei/integrated_scenarios/ulm/project2/data/statistics/wb.1970.1999.fldmean.nc'
nc = Dataset(ifile,'r')
lat = nc.variables['lat'][:]
lon = nc.variables['lon'][:]
nc.variables
# Out:
# OrderedDict([(u'lon', <netCDF4.Variable object at 0x69bf6d0>), (u'lat', <netCDF4.Variable object at 0x69bf350>), (u'Time', <netCDF4.Variable object at 0x69bf150>), (u'Q', <netCDF4.Variable object at 0x79343d0>), (u'Evap', <netCDF4.Variable object at 0x7934350>), (u'Rainf', <netCDF4.Variable object at 0x79342d0>), (u'SoilMoist', <netCDF4.Variable object at 0x7934250>), (u'SWE', <netCDF4.Variable object at 0x79341d0>)])

# %%
Prec = nc.variables['Rainf'][:,0,0]
Prec.shape
# Out:
# (120,)

# %%
start = dt.datetime(1950,1,1)
end = dt.datetime(1959,12,31)
dates = pd.date_range(start=start,end=end,freq='M')
df = pd.DataFrame(Prec,index=dates,columns=['Prec'])

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
df['Prec'].plot(ax=ax)
ax.set_ylabel('Prec (mm/day)')
pds.rolling_mean(df['Prec'],5,center=True).plot(ax=ax,style='k-',linewidth=3.5)
fig.savefig('ts.prec.png')

# %%
def water_month(indate):
    moy = indate
    if moy >= 10:
        outmonth = moy - 10
    else:
        outmonth = moy + 2
    return outmonth

# %%
fig = plt.figure(figsize=(10,8))
months=['Oct','Nov','Dec','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep']
ax = fig.add_subplot(111)
ax.set_ylabel('Prec (mm/day)')
df['Prec'].groupby(lambda x: water_month(x.month)).mean().plot(ax=ax)
ax.set_xlim([-0.5,11.5])
ax.set_xticks(np.arange(12))
ax.set_xticklabels(months)
fig.savefig('clm.prec.png')

# %%
SWE = nc.variables['SWE'][:,0,0]
df['SWE'] = SWE

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
df['SWE'].plot(ax=ax)
ax.set_ylabel('SWE (mm)')
fig.savefig('ts.swe.png')

# %%
fig = plt.figure(figsize=(10,8))
months=['Oct','Nov','Dec','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep']
ax = fig.add_subplot(111)
ax.set_ylabel('SWE (mm)')
df['SWE'].groupby(lambda x: water_month(x.month)).mean().plot(ax=ax)
ax.set_xlim([-0.5,11.5])
ax.set_xticks(np.arange(12))
ax.set_xticklabels(months)
fig.savefig('clm.swe.png')
