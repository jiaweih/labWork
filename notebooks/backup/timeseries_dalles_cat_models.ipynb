# %%
from mpl_toolkits.basemap import Basemap, cm
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import datetime as dt
from netCDF4 import date2num, num2date
import pandas as pd
import pandas.stats.moments as pds
import os
# %matplotlib inline

# %%
parent_dir = '/raid3/jiawei/integrated_scenarios/CCSM4/simulator/{}/timeseries/basins' 
positions = ['-124.594,-116,42,52.8438','-116,-103.031,42,52.8438','-124,-116,29.0312,42','-116,-103.031,29.0312,42']
pos_names = ['PNW','Interior','California','SW']

fig_size = (20,16)
fmt = 'b-'
fmt_mean = 'b-'
fmt_smoothing = 'r'
linewidth = 1.5
linewidth_moving = 2.5
legend_loc = 'best'
legend_size = 16
height_ratio = [1,1]
width_ratio = [1,1]
wspace = 0.15
hspace = 0.15
label_size = 19
tick_size = 18
start = None
end = None

# %%
from functions_timeseries import water_month,get_data_ts,get_vmin_vmax_ts,get_yunit,figure_monthly_mean
from functions_common import get_var_name

# %% [markdown]
# ##CCSM4

# %% [markdown]
# <center> CCSM4 </center>

# %% [markdown]
# <center>Mean Monthly of the Dalles for Historical</center>

# %%
def figure_mean_monthly_basin(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,fmts,
                               linewidth,legend_loc,legend_size,xlabel,label_size,tick_size,text_size,store_dir):
    months=['Oct','Nov','Dec','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep']
    for basin in basins:
        fig = plt.figure(figsize=fig_size)
        ax = fig.add_subplot(111)
        idx = 0
        for scenario in scenarios:
            for var in variables:
                file_fldmean = plot_dir.format(scenario,basin,var)
                df = get_data_ts(file_fldmean,start,end)
                fmt=fmts[idx]
                fig_txt = "{} ({})".format(var,scenario)
                df.groupby(lambda x: water_month(x.month)).mean().plot(style=fmt,label=fig_txt,linewidth=4)
                idx+=1
        y_unit='[mm/day]'
        ax.legend(loc=legend_loc,prop={'size':legend_size},**{'frameon':False})
        ax.set_xlabel(xlabel,fontsize=label_size)
        ax.set_ylabel(y_unit,fontsize=label_size)
        ax.set_ylim([ymin_limit,ymax_limit])
        ax.set_xticks(np.arange(12))
        ax.set_xlim([-0.5,11.5])
        ax.set_xticklabels(months)
        ax.tick_params(axis='both',which='major',labelsize=tick_size)
        ax.text(0.08,0.97,basin,verticalalignment='top',horizontalalignment='left',transform=ax.transAxes,
                color='black',fontsize=text_size)
        fig.savefig(store_dir,dpi=300)

# %%
xlabel = 'Month'
variables=['PREC','FLOW']
scenarios = ['historical','rcp45','rcp85']
basins=['Dalles']
fig_size = (15,10)
ymin_limit = 0
ymax_limit = 5
fmts = ['k-','b-','k--','b--','k-.','b-.']
text_size = 24
parent_dir = '/raid3/jiawei/integrated_scenarios/CCSM4/simulator/{}/timeseries/basins'
plot_dir = parent_dir + '/{}/fldmean_month_series_{}'
store_dir = '/home/ftp/pub/jiawei/Integrated_Scenarios/CCSM4/timeseries/basins/dalle/mean_monthly_dalle.png'
figure_mean_monthly_basin(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,fmts,
                               linewidth,legend_loc,legend_size,xlabel,label_size,tick_size,text_size,store_dir)

# %% [markdown]
# <center>Monthly Mean of the Dalles for Historical</center>

# %%
def figure_monthly_mean_basin_QPE(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,
                              fmts,smoothing_step,linewidth,linewidth_moving,legend_loc,legend_size,
                              xlabel,label_size,tick_size,text_size,store_dir):
    for basin in basins:
        for scenario in scenarios:
            fig = plt.figure(figsize=fig_size)
            ax = fig.add_subplot(111)
            for idx,var in enumerate(variables):             
                file_fldmean = plot_dir.format(scenario,basin,var)
                df = get_data_ts(file_fldmean,start,end)
                fmt_smoothing = fmts[idx]
                fig_txt_smoothing = '{}'.format(var)                                             
                pds.rolling_mean(df,smoothing_step,center=True).plot(style=fmt_smoothing,label=fig_txt_smoothing,
                                                                     linewidth=linewidth_moving)
            y_unit=get_yunit(var)
            ax.legend(loc=legend_loc,prop={'size':legend_size})
            ax.set_xlabel(xlabel,fontsize=label_size)
            ax.set_ylabel(y_unit,fontsize=label_size)
            ax.set_ylim([ymin_limit,ymax_limit])
            ax.tick_params(axis='both',which='major',labelsize=tick_size)
            ax.text(0.06,0.97,basin,verticalalignment='top',horizontalalignment='left',transform=ax.transAxes,
                    color='black',fontsize=text_size)
            suptitle = '60 Months Moving Average of Precipitation, Evaporation and Flow for Historical'
            fig.suptitle(suptitle,fontsize=20)
            store_dir = store_dir.format(basin,var)                
            fig.savefig(store_dir,dpi=300)

# %%
def figure_monthly_mean_basin_QPE_cat(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,
                              fmts,smoothing_step,linewidth,linewidth_moving,linewidth_axv,legend_loc,legend_size,
                              xlabel,label_size,tick_size,text_size,store_dir):
    for basin in basins:
        for scenario in scenarios:
            fig = plt.figure(figsize=fig_size)
            ax = fig.add_subplot(111)
            idx = 0
            for model in models: 
                for var in variables:
                    file_fldmean = plot_dir.format(model,scenario,basin,scenario,var)
                    df = get_data_ts(file_fldmean,start,end)
                    fmt_smoothing = fmts[idx]
                    fig_txt_smoothing = '{} ({})'.format(var,model)                                             
                    pds.rolling_mean(df,smoothing_step,center=True).plot(style=fmt_smoothing,label=fig_txt_smoothing,
                                                                     linewidth=linewidth_moving)
                    idx+=1
            y_unit=get_yunit(var)
            div=dt.datetime(2005,12,31)
            ax.axvline(x=div,linewidth=linewidth_axv,color=color_axv)
            ax.legend(loc=legend_loc,prop={'size':legend_size})
            ax.set_xlabel(xlabel,fontsize=label_size)
            ax.set_ylabel(y_unit,fontsize=label_size)
            ax.set_ylim([ymin_limit,ymax_limit])
            ax.tick_params(axis='both',which='major',labelsize=tick_size)
            ax.text(0.06,0.97,basin,verticalalignment='top',horizontalalignment='left',transform=ax.transAxes,
                    color='black',fontsize=text_size)
            suptitle = 'Historical & {} {} months Moving Average'.format(scenario,smoothing_step)
            fig.suptitle(suptitle,fontsize=20)
            store_dir = store_dir.format(scenario)                
            fig.savefig(store_dir,dpi=300)

# %%
fig_size=(15,10)
xlabel = 'Year'
variables=['PREC','EVAP','FLOW']
basins = ['Dalles']
models = ['MIROC5','CCSM4']

#parent_dir = '/raid3/jiawei/integrated_scenarios/{}/simulator/{}/timeseries/basins'
plot_dir = parent_dir + '/{}/fldmean_month_series_{}_hist_cat_{}'
store_dir = '/home/ftp/pub/jiawei/Integrated_Scenarios/CCSM4/timeseries/basins/dalle/monthly_mean_QPE_models.png'
scenarios=['rcp45','rcp85']
ymax_limit = 5
ymin_limit = 0
smoothing_step = 60
text_size = 24
fmts = ['b','g','c','b--','g--','c--']
linewidth_axv = 3
color_axv = 'k'
linewidth_moving = 3
figure_monthly_mean_basin_QPE_cat(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,
                              fmts,smoothing_step,linewidth,linewidth_moving,linewidth_axv,legend_loc,legend_size,
                              xlabel,label_size,tick_size,text_size,store_dir)

# %%
def figure_monthly_mean_basin_QPE_cat_test(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,
                              fmts,smoothing_step,linewidth,linewidth_moving,linewidth_axv,legend_loc,legend_size,
                              xlabel,label_size,tick_size,text_size,store_dir):
    for basin in basins:
        for scenario in scenarios:
            fig = plt.figure(figsize=fig_size)
            ax = fig.add_subplot(111)
            idx = 0
            for model in models: 
                for var in variables:
                    file_fldmean = plot_dir.format(basin,model,scenario,var)
                    df = get_data_ts(file_fldmean,start,end)
                    fmt_smoothing = fmts[idx]
                    fig_txt_smoothing = '{} ({})'.format(var,model)                                             
                    pds.rolling_mean(df,smoothing_step,center=True).plot(style=fmt_smoothing,label=fig_txt_smoothing,
                                                                     linewidth=linewidth_moving)
                    idx+=1
            y_unit=get_yunit(var)
            div=dt.datetime(2005,12,31)
            ax.axvline(x=div,linewidth=linewidth_axv,color=color_axv)
            ax.legend(loc=legend_loc,prop={'size':legend_size})
            ax.set_xlabel(xlabel,fontsize=label_size)
            ax.set_ylabel(y_unit,fontsize=label_size)
            ax.set_ylim([ymin_limit,ymax_limit])
            ax.tick_params(axis='both',which='major',labelsize=tick_size)
            ax.text(0.06,0.97,basin,verticalalignment='top',horizontalalignment='left',transform=ax.transAxes,
                    color='black',fontsize=text_size)
            suptitle = 'Historical & {} {} months Moving Average'.format(scenario,smoothing_step)
            fig.suptitle(suptitle,fontsize=20)
            store_dir = store_dir.format(scenario)                
            fig.savefig(store_dir,dpi=300)

# %%
fig_size=(15,10)
xlabel = 'Year'
variables=['PREC','EVAP','FLOW']
basins = ['dalle']
models = ['CCSM4']

parent_dir = '/raid3/muxiao/matt/data/{}'
plot_dir = parent_dir + '/{}/fldmean_month_series_{}_hist_cat_{}'
store_dir = '/home/ftp/pub/jiawei/Integrated_Scenarios/CCSM4/timeseries/basins/dalle/monthly_mean_QPE_models.png'
scenarios=['rcp45','rcp85']
ymax_limit = 5
ymin_limit = 0
smoothing_step = 60
text_size = 24
fmts = ['b','g','c','b--','g--','c--']
linewidth_axv = 3
color_axv = 'k'
linewidth_moving = 3
figure_monthly_mean_basin_QPE_cat_test(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,
                              fmts,smoothing_step,linewidth,linewidth_moving,linewidth_axv,legend_loc,legend_size,
                              xlabel,label_size,tick_size,text_size,store_dir)

# %%
def figure_monthly_mean_basin_QPE_test(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,
                              fmts,smoothing_step,linewidth,linewidth_moving,linewidth_axv,legend_loc,legend_size,
                              xlabel,label_size,tick_size,text_size,store_dir):
    for basin in basins:
        for scenario in scenarios:
            fig = plt.figure(figsize=fig_size)
            ax = fig.add_subplot(111)
            for idx,var in enumerate(variables): 
                for model in models:
                    file_fldmean = plot_dir.format(model,scenario,basin,scenario,var)
                    df = get_data_ts(file_fldmean,start,end)
                    fmt_smoothing = fmts[idx]
                    fig_txt_smoothing = '{}'.format(var)                                             
                    pds.rolling_mean(df,smoothing_step,center=True).plot(style=fmt_smoothing,label=fig_txt_smoothing,
                                                                     linewidth=linewidth_moving)
            y_unit=get_yunit(var)
            div=dt.datetime(2005,12,31)
            ax.axvline(x=div,linewidth=linewidth_axv,color=color_axv)
            ax.legend(loc=legend_loc,prop={'size':legend_size})
            ax.set_xlabel(xlabel,fontsize=label_size)
            ax.set_ylabel(y_unit,fontsize=label_size)
            ax.set_ylim([ymin_limit,ymax_limit])
            ax.tick_params(axis='both',which='major',labelsize=tick_size)
            ax.text(0.06,0.97,basin,verticalalignment='top',horizontalalignment='left',transform=ax.transAxes,
                    color='black',fontsize=text_size)
            suptitle = 'Historical & {} {} months Moving Average'.format(scenario,smoothing_step)
            fig.suptitle(suptitle,fontsize=20)
            store_dir = store_dir.format(scenario)                
            fig.savefig(store_dir,dpi=300)

# %%
fig_size=(15,10)
xlabel = 'Year'
variables=['PREC','EVAP','FLOW']
basins = ['Dalles']
models = ['CCSM4','MIROC5']
parent_dir = '/raid3/jiawei/integrated_scenarios/{}/simulator/{}/timeseries/basins'
plot_dir = parent_dir + '/{}/fldmean_month_series_{}_hist_cat_{}'
store_dir = '/home/ftp/pub/jiawei/Integrated_Scenarios/CCSM4/timeseries/basins/dalle/monthly_mean_QPE_{}.png'
scenarios=['rcp45']
ymax_limit = 5
ymin_limit = 0
smoothing_step = 60
text_size = 24
fmts = ['b','g','c','b--','g--','c--']
linewidth_axv = 3
color_axv = 'k'
figure_monthly_mean_basin_QPE_test(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,
                              fmts,smoothing_step,linewidth,linewidth_moving,linewidth_axv,legend_loc,legend_size,
                              xlabel,label_size,tick_size,text_size,store_dir)

# %%
fig_size=(15,10)
xlabel = 'Year'
variables=['PREC','EVAP','FLOW']
basins = ['Dalles']
parent_dir = '/raid3/jiawei/integrated_scenarios/CCSM4/simulator/{}/timeseries/basins'
plot_dir = parent_dir + '/{}/fldmean_month_series_{}_hist_cat_{}'
store_dir = '/home/ftp/pub/jiawei/Integrated_Scenarios/CCSM4/timeseries/basins/dalle/monthly_mean_QPE_{}.png'
scenarios=['rcp85']
ymax_limit = 5
ymin_limit = 0
smoothing_step = 60
text_size = 24
fmts = ['b','g','c']
linewidth_axv = 3
color_axv = 'k'
figure_monthly_mean_basin_QPE_cat(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,
                              fmts,smoothing_step,linewidth,linewidth_moving,linewidth_axv,legend_loc,legend_size,
                              xlabel,label_size,tick_size,text_size,store_dir)

# %% [markdown]
# ###MIROC5

# %% [markdown]
# <center>MIROC5</center>

# %%
parent_dir = '/raid3/jiawei/integrated_scenarios/MIROC5/simulator/{}/timeseries/basins'
xlabel = 'Month'
variables=['PREC','FLOW']
scenarios = ['historical','rcp45','rcp85']
basins=['Dalles']
fig_size = (15,10)
ymin_limit = 0
ymax_limit = 5
fmts = ['k-','b-','r-','k--','b--','r--','k-.','b-.','r-.']
text_size = 24
plot_dir = parent_dir + '/{}/fldmean_month_series_{}'
store_dir = '/home/ftp/pub/jiawei/Integrated_Scenarios/MIROC5/timeseries/basins/dalle/mean_monthly_dalle.png'
figure_mean_monthly_basin(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,fmts,
                               linewidth,legend_loc,legend_size,xlabel,label_size,tick_size,text_size,store_dir)

# %%
fig_size=(15,10)
xlabel = 'Year'
variables=['PREC','EVAP','FLOW']
basins = ['Dalles']
parent_dir = '/raid3/jiawei/integrated_scenarios/MIROC5/simulator/{}/timeseries/basins'
plot_dir = parent_dir + '/{}/fldmean_month_series_{}_hist_cat_{}'
store_dir = '/home/ftp/pub/jiawei/Integrated_Scenarios/MIROC5/timeseries/basins/dalle/monthly_mean_QPE_{}.png'
scenarios=['rcp45']
ymax_limit = 5
ymin_limit = 0
smoothing_step = 60
text_size = 24
fmts = ['b','g','c']
linewidth_axv = 3
color_axv = 'k'
figure_monthly_mean_basin_QPE_cat(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,
                              fmts,smoothing_step,linewidth,linewidth_moving,linewidth_axv,legend_loc,legend_size,
                              xlabel,label_size,tick_size,text_size,store_dir)

# %%
fig_size=(15,10)
xlabel = 'Year'
variables=['PREC','EVAP','RUNOFF']
basins = ['Dalles']
parent_dir = '/raid3/jiawei/integrated_scenarios/MIROC5/simulator/{}/timeseries/basins'
plot_dir = parent_dir + '/{}/fldmean_month_series_{}_hist_cat_{}'
store_dir = '/home/ftp/pub/jiawei/Integrated_Scenarios/MIROC5/timeseries/basins/dalle/monthly_mean_QPE_{}.png'
scenarios=['rcp85']
ymax_limit = 5
ymin_limit = 0
smoothing_step = 60
text_size = 24
fmts = ['b','g','c']
linewidth_axv = 3
color_axv = 'k'
figure_monthly_mean_basin_QPE_cat(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,
                              fmts,smoothing_step,linewidth,linewidth_moving,linewidth_axv,legend_loc,legend_size,
                              xlabel,label_size,tick_size,text_size,store_dir)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-3d1a40680477> in <module>()
#      16 figure_monthly_mean_basin_QPE_cat(plot_dir,basins,scenarios,variables,ymin_limit,ymax_limit,start,end,fig_size,
#      17                               fmts,smoothing_step,linewidth,linewidth_moving,linewidth_axv,legend_loc,legend_size,
# ---> 18                               xlabel,label_size,tick_size,text_size,store_dir)
#
# <ipython-input-16-32e225ebebba> in figure_monthly_mean_basin_QPE_cat(plot_dir, basins, scenarios, variables, ymin_limit, ymax_limit, start, end, fig_size, fmts, smoothing_step, linewidth, linewidth_moving, linewidth_axv, legend_loc, legend_size, xlabel, label_size, tick_size, text_size, store_dir)
#      10                 for var in variables:
#      11                     file_fldmean = plot_dir.format(model,scenario,basin,scenario,var)
# ---> 12                     df = get_data_ts(file_fldmean,start,end)
#      13                     fmt_smoothing = fmts[idx]
#      14                     fig_txt_smoothing = '{} ({})'.format(var,model)
#
# /home/raid3/jiawei/integrated_scenarios/nb/CCSM4/functions_timeseries.pyc in get_data_ts(ifile, start, end, timname)
#      27 ### data are timeseries, outputs are dataframe, with the index being time
#      28 def get_data_ts(ifile,start=None,end=None,timname='Time'):
# ---> 29     nc = Dataset(ifile,'r')
#      30     for key in nc.variables.keys():
#      31         if key not in nc.dimensions.keys():
#
# /usr/local/lib/python2.7/site-packages/netCDF4.so in netCDF4.Dataset.__init__ (netCDF4.c:16538)()
#
# RuntimeError: No such file or directory

# %% [raw]
# <style type="text/css">
# .input, .output_prompt {
# display:none !important;
# }
# </style>
