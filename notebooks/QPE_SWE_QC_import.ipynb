# %%
from mpl_toolkits.basemap import Basemap, cm
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib as mpl
# %matplotlib inline

# %% [markdown]
# ## <center>Precipitation, Evaporation, and Runoff </center>

# %%
from functions_common import get_data,plot_basemap,cbar_extend,plot_colorbar,get_var_name,cbar_unit
from functions_QPE import get_vmin_vmax_QPE,plot_figure_QPE

# %%
variables= ['PREC','EVAP','FLOW']
store_dir = '/home/ftp/pub/jiawei/Integrated_Scenarios/CCSM4/Q_P_E/Q_P_E_{}.png'    ####
source_dir = '/raid3/jiawei/integrated_scenarios/CCSM4/simulator/{}/Q_P_E/{}_mean_avg_avg.nc'   #####
border = 1 
fig_size = (12,10)
cbar_tick_size = 16
cbar_label_size = 18
text_size = 20
cax = [0.1,0.25,0.85,0.03]
orientation = 'horizontal'

# %%
vmin = 0
vmax = 5
cmap = cm.GMT_drywet
scenarios = ['historical']   ####
extend = 'max'
plot_figure_QPE(source_dir,variables,scenarios,fig_size,border,cmap,orientation,cbar_tick_size,\
                cbar_label_size,vmin,vmax,text_size,cax,extend,store_dir)

# %% [markdown]
# ## <center>SWE of April 1 for historical, rcp45, and rcp85

# %%
from functions_SWE import get_vmin_vmax_SWE,plot_figure_SWE

# %%
variables= ['SWE']
store_dir = '/home/ftp/pub/jiawei/Integrated_Scenarios/IPSL-CM5A-MR/{}_04_01.png'
source_dir = '/raid3/jiawei/integrated_scenarios/IPSL-CM5A-MR/simulator/{}/{}/data/04_01_day1'
vmin = 10
vmax = 250
cmap = cm.GMT_drywet
scenarios = ['historical','rcp45','rcp85']
plot_figure_SWE(source_dir,variables,scenarios,fig_size,border,cmap,orientation,cbar_tick_size,\
                cbar_label_size,vmin,vmax,text_size,cax,extend,store_dir)
