# %%
from mpl_toolkits.basemap import Basemap, cm
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib as mpl
# %matplotlib inline

# %%
from functions_common import get_data,plot_basemap,cbar_extend,plot_colorbar,cbar_unit
from test6 import get_vmin_vmax_seasonal,plot_figure_seasonal

# %%
var_names = {'PREC':'precipitation','EVAP':'Evaporation','SOIL_MOIST':'Soil_moisture','FLOW':'Flow','SWE':'SWE',\
             'TMAX':'air_temp_tmax','TMIN':'air_temp_tmin','TAVG':'air_temp_tavg'}
seasons = [ 'SON', 'DJF','MAM','JJA']
#parent_dir = '/raid3/jiawei/integrated_scenarios/CCSM4/simulator/{}/seasonal/{}/seasons{}.nc4'
store_dir = '/home/ftp/pub/jiawei/Integrated_Scenarios/CCSM4/seasonal/{}_seasonal_{}.png'
fig_size = (12,10)
nrow = 2
ncol = 2
height_ratio = [1,1]
width_ratio = [1,1]
wspace = 0.01
hspace = 0.05
border = 1
cbar_cax = [0.14,0.08,0.75,0.03]
cbar_tick_size = 15
cbar_label_size = 18
text_size = 16
orientation = 'horizontal'

# %% [markdown]
# <center>Forcing Data (Historical)

# %%
parent_dir = '/raid3/jiawei/integrated_scenarios/CCSM4/simulator/{}/seasonal/forcing/{}/seasons{}.nc4'
scenarios = ['historical']

# %% [markdown]
# ### Prec

# %%
variables = ['PREC']
cmap = cm.GMT_drywet
vmin = 0
vmax = 8
plot_figure_seasonal(parent_dir,store_dir,scenarios,variables,var_names,seasons,fig_size,nrow,ncol,height_ratio,width_ratio,\
                    wspace,hspace,border,vmin,vmax,cbar_cax,cbar_tick_size,cbar_label_size,text_size,cmap,orientation)

# %% [markdown]
# ### Tmax

# %%
variables = ['TMAX']
vmin = -10
vmax = 40
cmap = plt.cm.jet
plot_figure_seasonal(parent_dir,store_dir,scenarios,variables,var_names,seasons,fig_size,nrow,ncol,height_ratio,width_ratio,\
                    wspace,hspace,border,vmin,vmax,cbar_cax,cbar_tick_size,cbar_label_size,text_size,cmap,orientation)

# %% [markdown]
# ###Tmin

# %%
variables = ['TMIN']
cmap = plt.cm.jet
vmin = -30
vmax = 30
plot_figure_seasonal(parent_dir,store_dir,scenarios,variables,var_names,seasons,fig_size,nrow,ncol,height_ratio,width_ratio,\
                    wspace,hspace,border,vmin,vmax,cbar_cax,cbar_tick_size,cbar_label_size,text_size,cmap,orientation)

# %% [markdown]
# <center>Forcing Data (rcp45)

# %%
parent_dir = '/raid3/jiawei/integrated_scenarios/CCSM4/simulator/{}/seasonal/forcing/{}/seasons{}.nc4'
scenarios = ['rcp45']

# %% [markdown]
# ###Precipitation

# %%
variables = ['PREC']
cmap = cm.GMT_drywet
vmin = 0
vmax = 8
plot_figure_seasonal(parent_dir,store_dir,scenarios,variables,var_names,seasons,fig_size,nrow,ncol,height_ratio,width_ratio,\
                    wspace,hspace,border,vmin,vmax,cbar_cax,cbar_tick_size,cbar_label_size,text_size,cmap,orientation)

# %% [markdown]
# ###Tmax

# %%
variables = ['TMAX']
vmin = -10
vmax = 40
cmap = plt.cm.jet
plot_figure_seasonal(parent_dir,store_dir,scenarios,variables,var_names,seasons,fig_size,nrow,ncol,height_ratio,width_ratio,\
                    wspace,hspace,border,vmin,vmax,cbar_cax,cbar_tick_size,cbar_label_size,text_size,cmap,orientation)

# %% [markdown]
# ###Tmin

# %%
variables = ['TMIN']
cmap = plt.cm.jet
vmin = -30
vmax = 30
plot_figure_seasonal(parent_dir,store_dir,scenarios,variables,var_names,seasons,fig_size,nrow,ncol,height_ratio,width_ratio,\
                    wspace,hspace,border,vmin,vmax,cbar_cax,cbar_tick_size,cbar_label_size,text_size,cmap,orientation)

# %% [markdown]
# ##Difference of precipitation between forcing data and output (Forcing - Output)

# %% [markdown]
#  <center>Precipitation ( Forcing - Output )

# %%
parent_dir = '/raid3/jiawei/integrated_scenarios/CCSM4/simulator/{}/seasonal/diff/forcing/{}/seasons{}.nc4'

# %%
variables = ['PREC']
scenarios = ['historical']
cmap = plt.cm.seismic_r
vmin = -0.01
vmax = 0.01
plot_figure_seasonal(parent_dir,store_dir,scenarios,variables,var_names,seasons,fig_size,nrow,ncol,height_ratio,width_ratio,\
                    wspace,hspace,border,vmin,vmax,cbar_cax,cbar_tick_size,cbar_label_size,text_size,cmap,orientation)

# %% [markdown]
# ##Differences of forcing data between rcp45 and historical (rcp45 - historical)

# %% [markdown]
#  <center>Forcing Data ( rcp45 - historical )

# %%
parent_dir = '/raid3/jiawei/integrated_scenarios/CCSM4/simulator/{}/seasonal/forcing/diff/{}/seasons{}.nc4'
scenarios = ['rcp45']

# %% [markdown]
# ###Precipitation

# %%
variables = ['PREC']
cmap = plt.cm.seismic_r
vmin = -3
vmax = 3
plot_figure_seasonal(parent_dir,store_dir,scenarios,variables,var_names,seasons,fig_size,nrow,ncol,height_ratio,width_ratio,\
                    wspace,hspace,border,vmin,vmax,cbar_cax,cbar_tick_size,cbar_label_size,text_size,cmap,orientation)

# %% [markdown]
# ###Tmax

# %%
variables = ['TMAX']
cmap = plt.cm.YlOrRd
vmin = -0.2
vmax = 3.8
plot_figure_seasonal(parent_dir,store_dir,scenarios,variables,var_names,seasons,fig_size,nrow,ncol,height_ratio,width_ratio,\
                    wspace,hspace,border,vmin,vmax,cbar_cax,cbar_tick_size,cbar_label_size,text_size,cmap,orientation)

# %% [markdown]
# ###Tmin

# %%
variables = ['TMIN']
cmap = plt.cm.YlOrRd
vmin = 0
vmax = 3.3
plot_figure_seasonal(parent_dir,store_dir,scenarios,variables,var_names,seasons,fig_size,nrow,ncol,height_ratio,width_ratio,\
                    wspace,hspace,border,vmin,vmax,cbar_cax,cbar_tick_size,cbar_label_size,text_size,cmap,orientation)

# %% [raw]
# <style type="text/css">
# .input, .output_prompt {
# display:none !important;
# }
# </style>
